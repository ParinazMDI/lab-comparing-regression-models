# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
customer_df=pd.read_csv("we_fn_use_c_marketing_customer_value_analysis.csv")
display(customer_df.head())
display(customer_df.shape)
display(customer_df.info)
display(customer_df.dtypes)
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
# Rename the columns
customer_df.columns=customer_df.columns.str.lower().str.replace(" ","_")
customer_df.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   effective_to_date employmentstatus gender  income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   months_since_policy_inception number_of_open_complaints  number_of_policies  \
# ...

# %%
customer_df['effective_to_date'] = pd.to_datetime(customer_df['effective_to_date'],format='%m/%d/%y')
customer_df['effective_to_date']
# Out:
# 0      2011-02-24
# 1      2011-01-31
# 2      2011-02-19
# 3      2011-01-20
# 4      2011-02-03
#           ...
# 9129   2011-02-10
# 9130   2011-02-12
# 9131   2011-02-06
# 9132   2011-02-03
# 9133   2011-02-14
# Name: effective_to_date, Length: 9134, dtype: datetime64[ns]

# %%
numerical_df = customer_df.select_dtypes(np.number)
numerical_df.head()
# Out:
#    customer_lifetime_value  income  monthly_premium_auto  \
# 0              2763.519279   56274                    69
# 1              6979.535903       0                    94
# 2             12887.431650   48767                   108
# 3              7645.861827       0                   106
# 4              2813.692575   43836                    73
#
#    months_since_last_claim  months_since_policy_inception  \
# 0                       32                              5
# 1                       13                             42
# 2                       18                             38
# 3                       18                             65
# 4                       12                             44
#
#    number_of_open_complaints  number_of_policies  total_claim_amount
# 0                          0                   1          384.811147
# 1                          0                   8         1131.464935
# ...

# %%
def numerical_type(data,threshold = 10):
    continous_columns = []
    discrete_columns = []
    
    for column in data.columns:
        if data[column].nunique() > threshold:
            continous_columns.append(column)
        else:
            discrete_columns.append(column)
    continous_df=data[continous_columns]
    discrete_df=data[discrete_columns]
    
    return continous_df,discrete_df

# %%
continuous_df, discrete_df = numerical_type(numerical_df)

# %%
continuous_df
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %%
discrete_df
# Out:
#       number_of_open_complaints  number_of_policies
# 0                             0                   1
# 1                             0                   8
# 2                             0                   2
# 3                             0                   7
# 4                             0                   1
# ...                         ...                 ...
# 9129                          0                   2
# 9130                          0                   1
# 9131                          3                   2
# 9132                          0                   3
# 9133                          0                   1
#
# [9134 rows x 2 columns]

# %%
numerical_df.dtypes
# Out:
# customer_lifetime_value          float64
# income                             int64
# monthly_premium_auto               int64
# months_since_last_claim            int64
# months_since_policy_inception      int64
# number_of_open_complaints          int64
# number_of_policies                 int64
# total_claim_amount               float64
# dtype: object

# %%
import matplotlib.pyplot as plt    # pay attention that clv and i and mpa bayad bashe hatman
import seaborn as sns
correlations_matrix = numerical_df.corr()   
sns.heatmap(correlations_matrix, annot=True)
plt.show()

# %%
# Count Plot
for column in discrete_df.columns:
    sns.countplot(x=column, data=discrete_df)
    plt.show()

# %%
#Histogram
for column in continuous_df.columns:
    sns.histplot(continuous_df[column], kde=True)
    plt.show()

# %% [markdown]
# # Statistical interpretations:
#
# -Monthly Premium Auto Right Skew:
# The right skew in the "monthly_premium_auto" column suggests that the distribution of monthly auto insurance premiums is positively skewed. This means that the majority of policyholders have lower premiums, and there are relatively fewer policyholders with higher premiums.
#
# -Majority of People Have No Income:
# The fact that the majority of people do not have any income is an important observation. It suggests a potential financial risk for insurance providers, as individuals with no income may have difficulties paying their insurance premiums.
#
# -Majority of Customers Have at Least 2 Policies:
# The observation that most customers have at least two insurance policies on their insurance is significant.
#
# -Company has been successful in addressing customer concerns:
# The fact that the number of open complaints is zero suggests that customers do not have any unresolved issues or complaints with the company. This can be seen as a positive sign of customer satisfaction.

# %%
#monthly_premium_auto have a righ skew 
#most placy is related to number one 
#from number 4 in policy they are almost in a same frequant
#income

# %%
for column in continuous_df.columns:
        sns.boxplot(x=continuous_df[column])
        plt.title(f'Box Plot for {column}')
        plt.xlabel(column)
        plt.show()

# %%
# We have outlier in monthly_premium_auto and customer_lifetime_value so lets take a look to them:

# %%
continuous_df["customer_lifetime_value"].value_counts(dropna=False)
# Out:
# 7200.664877     6
# 17497.522010    6
# 2248.449633     6
# 8092.876960     6
# 6057.072080     6
#                ..
# 9162.063169     1
# 2374.147419     1
# 6874.848270     1
# 9934.865795     1
# 2611.836866     1
# Name: customer_lifetime_value, Length: 8041, dtype: int64

# %%
#we do not have a null value
numerical_df.isnull().sum()
# Out:
# customer_lifetime_value          0
# income                           0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# total_claim_amount               0
# dtype: int64

# %%
#I decided to drop outliers
def remove_outliers_quantile(df,columns):
    for column in columns:
        Q1=df[column].quantile(0.25)
        Q3=df[column].quantile(0.75)
        IQR = Q3 - Q1

        lower_bound= Q1 - 1.5* IQR
        upper_bound = Q3 +1.5 * IQR
        df_clean=df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    
    return df_clean

# %%
# numerical_df= numerical_df.[numerical_df['customer_lifetime_value','monthly_premium_auto']].remove_outliers_quantile(numerical_df,'customer_lifetime_value','monthly_premium_auto')
# numerical_df
numerical_df = remove_outliers_quantile(numerical_df, ['customer_lifetime_value', 'monthly_premium_auto'])
numerical_df
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %%
for column in ['customer_lifetime_value', 'monthly_premium_auto']:
    sns.histplot(numerical_df[column], kde=True)
    plt.show()

# %%
#check for the null value
numerical_df.isnull().sum()
# Out:
# customer_lifetime_value          0
# income                           0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# total_claim_amount               0
# dtype: int64

# %%
numerical_df.shape
# Out:
# (8704, 8)

# %%
#Save the numerical_df to csv as numerical.csv
csv_file_path = "numerical.csv"

numerical_df.to_csv(csv_file_path, index=False)

# %% [markdown]
# # lab part 2 :

# %%
categoricals_df = customer_df.select_dtypes(object)

categoricals_df.head()
# Out:
#   customer       state response  coverage education employmentstatus gender  \
# 0  BU79786  Washington       No     Basic  Bachelor         Employed      F
# 1  QZ44356     Arizona       No  Extended  Bachelor       Unemployed      F
# 2  AI49188      Nevada       No   Premium  Bachelor         Employed      F
# 3  WW63253  California       No     Basic  Bachelor       Unemployed      M
# 4  HB64268  Washington       No     Basic  Bachelor         Employed      M
#
#   location_code marital_status     policy_type        policy renew_offer_type  \
# 0      Suburban        Married  Corporate Auto  Corporate L3           Offer1
# 1      Suburban         Single   Personal Auto   Personal L3           Offer3
# 2      Suburban        Married   Personal Auto   Personal L3           Offer1
# 3      Suburban        Married  Corporate Auto  Corporate L2           Offer1
# 4         Rural         Single   Personal Auto   Personal L1           Offer1
#
# ...

# %%
def plot_cat(Dataframe):
    for column in Dataframe.columns:
        sns.countplot(x=Dataframe[column])
        plt.show()
    return None
   

plot_cat(categoricals_df)

# %%
#we do not need customer column

# %%
categoricals_df.isna().sum()/len(categoricals_df)
# Out:
# customer            0.0
# state               0.0
# response            0.0
# coverage            0.0
# education           0.0
# employmentstatus    0.0
# gender              0.0
# location_code       0.0
# marital_status      0.0
# policy_type         0.0
# policy              0.0
# renew_offer_type    0.0
# sales_channel       0.0
# vehicle_class       0.0
# vehicle_size        0.0
# dtype: float64

# %%
#check for unique value
for column in categoricals_df.columns:
    unique_values = categoricals_df[column].unique()
    print(f'Unique values in column "{column}": {unique_values}')
# Out:
# Unique values in column "customer": ['BU79786' 'QZ44356' 'AI49188' ... 'TD14365' 'UP19263' 'Y167826']
# Unique values in column "state": ['Washington' 'Arizona' 'Nevada' 'California' 'Oregon']
# Unique values in column "response": ['No' 'Yes']
# Unique values in column "coverage": ['Basic' 'Extended' 'Premium']
# Unique values in column "education": ['Bachelor' 'College' 'Master' 'High School or Below' 'Doctor']
# Unique values in column "employmentstatus": ['Employed' 'Unemployed' 'Medical Leave' 'Disabled' 'Retired']
# Unique values in column "gender": ['F' 'M']
# Unique values in column "location_code": ['Suburban' 'Rural' 'Urban']
# Unique values in column "marital_status": ['Married' 'Single' 'Divorced']
# Unique values in column "policy_type": ['Corporate Auto' 'Personal Auto' 'Special Auto']
# Unique values in column "policy": ['Corporate L3' 'Personal L3' 'Corporate L2' 'Personal L1' 'Special L2'
#  'Corporate L1' 'Personal L2' 'Special L1' 'Special L3']
# ...

# %% [markdown]
# # ## Insights into categorical data
# column | decision
# -------|---------
# state | only 5 - leave as is
# response | imbalanced make 1,0
# coverage| ordinal encode
# education | combine master & dr.
# employment status | smallest 3 into other
# gender | 1hot encode
# location | ordinal encode as is
# marital | 1hot encode as is
# policy type | combine corporate/special
# policy | drop column
# renew offer | encode as is
# sales channel | 1hot encode as is
# vehicle class | 1hot combine luxury/sports
# vehicle size | ordinal encode

# %%
#check for the number of the unique value:
categoricals_df.nunique()
# Out:
# customer            9134
# state                  5
# response               2
# coverage               3
# education              5
# employmentstatus       5
# gender                 2
# location_code          3
# marital_status         3
# policy_type            3
# policy                 9
# renew_offer_type       4
# sales_channel          4
# vehicle_class          6
# vehicle_size           3
# dtype: int64

# %%
#it is better to drop the customer , it will not help us in future!
categoricals_df=categoricals_df.drop(["customer"],axis=1) 
categoricals_df.head(10)
# Out:
#         state response  coverage education employmentstatus gender  \
# 0  Washington       No     Basic  Bachelor         Employed      F
# 1     Arizona       No  Extended  Bachelor       Unemployed      F
# 2      Nevada       No   Premium  Bachelor         Employed      F
# 3  California       No     Basic  Bachelor       Unemployed      M
# 4  Washington       No     Basic  Bachelor         Employed      M
# 5      Oregon      Yes     Basic  Bachelor         Employed      F
# 6      Oregon      Yes     Basic   College         Employed      F
# 7     Arizona       No   Premium    Master       Unemployed      M
# 8      Oregon      Yes     Basic  Bachelor    Medical Leave      M
# 9      Oregon       No  Extended   College         Employed      F
#
#   location_code marital_status     policy_type        policy renew_offer_type  \
# 0      Suburban        Married  Corporate Auto  Corporate L3           Offer1
# ...

# %%
#check for the type that all make sense!
categoricals_df.dtypes
# Out:
# state               object
# response            object
# coverage            object
# education           object
# employmentstatus    object
# gender              object
# location_code       object
# marital_status      object
# policy_type         object
# policy              object
# renew_offer_type    object
# sales_channel       object
# vehicle_class       object
# vehicle_size        object
# dtype: object

# %%
#so i decided to create a new column called policy_level to only store the the amout of each level of policy we have.i will drop the policy column
categoricals_df["policy_level"] = categoricals_df["policy"].str.extract(r'L(\d)').astype(object)
categoricals_df["policy_level"].value_counts()
categoricals_df=categoricals_df.drop("policy",axis=1)
categoricals_df
# Out:
#            state response  coverage education employmentstatus gender  \
# 0     Washington       No     Basic  Bachelor         Employed      F
# 1        Arizona       No  Extended  Bachelor       Unemployed      F
# 2         Nevada       No   Premium  Bachelor         Employed      F
# 3     California       No     Basic  Bachelor       Unemployed      M
# 4     Washington       No     Basic  Bachelor         Employed      M
# ...          ...      ...       ...       ...              ...    ...
# 9129  California       No     Basic  Bachelor         Employed      M
# 9130  California      Yes  Extended   College         Employed      F
# 9131  California       No  Extended  Bachelor       Unemployed      M
# 9132  California       No  Extended   College         Employed      M
# 9133  California       No  Extended   College       Unemployed      M
#
#      location_code marital_status     policy_type renew_offer_type  \
# ...

# %% [markdown]
# # Compare policy_type and policy. What information is contained in these columns. Can you identify what is important?
#
#
# -Policy_type:
#
# It tells us the broad category or type of insurance coverage that a policy falls into.
# What's important in this column is understanding the type or category of insurance, as it helps classify policies into different groups for analysis or decision-making.
#
#
# -Policy:
#
# This column appears to provide more detailed information about the specific policy within a policy type. The unique values are 'Corporate L3', 'Personal L3', 'Corporate L2', 'Personal L1', 'Special L2', 'Corporate L1', 'Personal L2', 'Special L1', and 'Special L3'.It seems to contain information about the policy level, which could include aspects such as coverage level, policy tiers, or other policy-specific details.

# %% [markdown]
# # Check number of unique values in each column,  they can be combined in a way to ease encoding

# %%
#I decided to group some values together
def cleanOperation(x):  

    if 'Two-Door Car' in x:
        return 'Sports Car'
    elif 'Four-Door Car' in x:
        return 'SUV'
    else:
        return 'Luxury SUV'

categoricals_df['vehicle_class'] = list(map(cleanOperation, categoricals_df['vehicle_class']))
categoricals_df['vehicle_class'].value_counts()
# Out:
# SUV           4621
# Luxury SUV    2627
# Sports Car    1886
# Name: vehicle_class, dtype: int64

# %%
categoricals_df["renew_offer_type"] = categoricals_df["renew_offer_type"].str.extract('(\d+)').astype(object)
categoricals_df["renew_offer_type"].value_counts()

categoricals_df.head()
# Out:
#         state response  coverage education employmentstatus gender  \
# 0  Washington       No     Basic  Bachelor         Employed      F
# 1     Arizona       No  Extended  Bachelor       Unemployed      F
# 2      Nevada       No   Premium  Bachelor         Employed      F
# 3  California       No     Basic  Bachelor       Unemployed      M
# 4  Washington       No     Basic  Bachelor         Employed      M
#
#   location_code marital_status     policy_type renew_offer_type sales_channel  \
# 0      Suburban        Married  Corporate Auto                1         Agent
# 1      Suburban         Single   Personal Auto                3         Agent
# 2      Suburban        Married   Personal Auto                1         Agent
# 3      Suburban        Married  Corporate Auto                1   Call Center
# 4         Rural         Single   Personal Auto                1         Agent
#
#   vehicle_class vehicle_size policy_level
# 0    Sports Car      Medsize            3
# ...

# %%
categoricals_df.education = np.where(categoricals_df['education']=='High School or Below','College',categoricals_df.education)   
categoricals_df.education.value_counts(dropna=False)
# Out:
# College     5303
# Bachelor    2748
# Master       741
# Doctor       342
# Name: education, dtype: int64

# %%
mapping = {"College " : 0, "Bachelor" : .5, "Master" : 1, "Doctor":1}


categoricals_df["education"] =categoricals_df["education"].replace(mapping)

# %%
categoricals_df["employmentstatus"] = categoricals_df["employmentstatus"].map({"Medical Leave" : 0, "Disabled" : 0, "Unemployed" : 0, "Retired" : .5, "Employed":2})

# %%
categoricals_df["location_code"] =categoricals_df["location_code"].map({"Rural" : 0, "Suburban" :.5, "Urban" : 1,})

# %%
categoricals_df["vehicle_size"] =categoricals_df["vehicle_size"].map({"Small" : 0, "Medsize" :.5, "Large" : 1,})

# %%
mapping = {'Basic': 0, 'Extended':.5, 'Premium': 1}

# Use map to convert 'coverage' to numerical values
categoricals_df['coverage'] = categoricals_df['coverage'].replace(mapping)
categoricals_df['coverage'].value_counts(dropna=False)
# Out:
# 0.0    5568
# 0.5    2742
# 1.0     824
# Name: coverage, dtype: int64

# %%
#return the date column
categoricals_df['effective_to_date'] = customer_df['effective_to_date']
categoricals_df.head()
# Out:
#         state response  coverage education  employmentstatus gender  \
# 0  Washington       No       0.0       0.5               2.0      F
# 1     Arizona       No       0.5       0.5               0.0      F
# 2      Nevada       No       1.0       0.5               2.0      F
# 3  California       No       0.0       0.5               0.0      M
# 4  Washington       No       0.0       0.5               2.0      M
#
#    location_code marital_status     policy_type renew_offer_type  \
# 0            0.5        Married  Corporate Auto                1
# 1            0.5         Single   Personal Auto                3
# 2            0.5        Married   Personal Auto                1
# 3            0.5        Married  Corporate Auto                1
# 4            0.0         Single   Personal Auto                1
#
#   sales_channel vehicle_class  vehicle_size policy_level effective_to_date
# 0         Agent    Sports Car           0.5            3        2011-02-24
# ...

# %%
categoricals_df['effective_to_date'] = categoricals_df['effective_to_date'].astype(str)
date_split = categoricals_df['effective_to_date'].str.split('-', expand=True)
# Convert the components to integers
categoricals_df['Year'] = date_split[0]
categoricals_df['Month'] = date_split[1]
categoricals_df['Day'] = date_split[2]

# %%
categoricals_df.head()
# Out:
#         state response  coverage education  employmentstatus gender  \
# 0  Washington       No       0.0       0.5               2.0      F
# 1     Arizona       No       0.5       0.5               0.0      F
# 2      Nevada       No       1.0       0.5               2.0      F
# 3  California       No       0.0       0.5               0.0      M
# 4  Washington       No       0.0       0.5               2.0      M
#
#    location_code marital_status     policy_type renew_offer_type  \
# 0            0.5        Married  Corporate Auto                1
# 1            0.5         Single   Personal Auto                3
# 2            0.5        Married   Personal Auto                1
# 3            0.5        Married  Corporate Auto                1
# 4            0.0         Single   Personal Auto                1
#
#   sales_channel vehicle_class  vehicle_size policy_level effective_to_date  \
# 0         Agent    Sports Car           0.5            3        2011-02-24
# ...

# %%
sns.lineplot(x = categoricals_df['Day'], y=numerical_df['total_claim_amount'], hue = categoricals_df['Month'], palette="Set1");

# %%
sns.lineplot(x = categoricals_df['Day'],  y=numerical_df['total_claim_amount'])
# Out:
# <Axes: xlabel='Day', ylabel='total_claim_amount'>

# %%
sns.set(rc={'figure.figsize':(15,8)})
sns.lineplot(x="effective_to_date", y="total_claim_amount", data = customer_df)
# Out:
# <Axes: xlabel='effective_to_date', ylabel='total_claim_amount'>

# %% [markdown]
# - During the week of January 8 to January 15, 2011, there was a noticeable decrease in the claim amounts. Additionally, there was a subsequent increase in the middle of the first month of 2011. These fluctuations in claim amounts suggest a dynamic pattern within that specific timeframe.

# %%
#Save the categoricals_df to csv as categoricals.csv

csv_file_path = "categorical.csv"

categoricals_df.to_csv(csv_file_path, index=False)
